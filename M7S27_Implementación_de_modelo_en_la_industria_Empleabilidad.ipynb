# %%
import pandas as pd

# %%
dataset_path = r"C:\Users\KPaz\Downloads\BOOTCAMP\Proyecto_7\archive_titanic (1).zip"

# %%
df = pd.read_csv(dataset_path)

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass              Name   Sex   Age  SibSp  Parch  \
# 0          892         0       3  Kelly, Mr. James  male  34.5      0      0
#
#    Ticket    Fare Cabin Embarked
# 0  330911  7.8292   NaN        Q

# %%
# Vamos a usar un clasificador de bosque aleatorio:
from sklearn.ensemble import RandomForestClassifier

# %%
# Eliminamos columnas no deseadas:
df.drop(["PassengerId","Name","Cabin","Ticket"],axis=1,inplace=True)

# %%
# Recuento de valores faltantes en cada columna:
print(df.isnull().sum())
# Out:
# Survived     0
# Pclass       0
# Sex          0
# Age         86
# SibSp        0
# Parch        0
# Fare         1
# Embarked     0
# dtype: int64

# %%
# Eliminación de filas con valores faltantes:
df.dropna(subset=['Fare','Age'],inplace=True)
print(df.isnull().sum())
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
# Codificación One hot encoding para variables categóricas
# Creación Dymmies:
dummies = pd.get_dummies(df.Sex)
dummies2 = pd.get_dummies(df.Embarked)
#pd.get_dummies(df, columns=['Sex, 'Embarked']) dummies y eliminacion de columnas de una sola vez

# %%
# Agregamos el dataset de los dummies con el dataset original:
new_df = pd.concat([df,dummies,dummies2],axis='columns')
print(type(new_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Eliminamos columnas que no usaremos:
new_df.drop(['Sex','Embarked'],axis='columns',inplace=True)
print(new_df.head(10))

new_df.info()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  female   male      C      Q  \
# 0         0       3  34.5      0      0   7.8292   False   True  False   True
# 1         1       3  47.0      1      0   7.0000    True  False  False  False
# 2         0       2  62.0      0      0   9.6875   False   True  False   True
# 3         0       3  27.0      0      0   8.6625   False   True  False  False
# 4         1       3  22.0      1      1  12.2875    True  False  False  False
# 5         0       3  14.0      0      0   9.2250   False   True  False  False
# 6         1       3  30.0      0      0   7.6292    True  False  False   True
# 7         0       2  26.0      1      1  29.0000   False   True  False  False
# 8         1       3  18.0      0      0   7.2292    True  False   True  False
# 9         0       3  21.0      2      0  24.1500   False   True  False  False
#
#        S
# 0  False
# 1   True
# 2  False
# 3   True
# 4   True
# 5   True
# 6  False
# 7   True
# 8  False
# 9   True
# <class 'pandas.core.frame.DataFrame'>
# Index: 331 entries, 0 to 415
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  331 non-null    int64
#  1   Pclass    331 non-null    int64
#  2   Age       331 non-null    float64
#  3   SibSp     331 non-null    int64
#  4   Parch     331 non-null    int64
#  5   Fare      331 non-null    float64
#  6   female    331 non-null    bool
#  7   male      331 non-null    bool
#  8   C         331 non-null    bool
#  9   Q         331 non-null    bool
#  10  S         331 non-null    bool
# dtypes: bool(5), float64(2), int64(4)
# memory usage: 19.7 KB

# %%
# Dividimos el dataset en características y clase target:
x = new_df[new_df.columns.difference(['Survived'])]
y = new_df['Survived']

classifier = RandomForestClassifier()
classifier.fit(x, y)
# Out:
# RandomForestClassifier()

# %%
"""
Hacemos un head a X porque, a la hora de implementar nuestro
modelo en la API REST, es necesario enviar los datos en el mismo orden en el que
se entrenaron:
"""
x.head()
# Out:
#     Age      C     Fare  Parch  Pclass      Q      S  SibSp  female   male
# 0  34.5  False   7.8292      0       3   True  False      0   False   True
# 1  47.0  False   7.0000      0       3  False   True      1    True  False
# 2  62.0  False   9.6875      0       2   True  False      0   False   True
# 3  27.0  False   8.6625      0       3  False   True      0   False   True
# 4  22.0  False  12.2875      1       3  False   True      1    True  False

# %% [markdown]
# A continuación, necesitamos conservar el modelo. El entorno donde implementamos la aplicación a menudo es diferente de donde los entrenamos. La capacitación, por lo general, requiere un conjunto diferente de recursos. Por lo tanto, esta separación ayuda a las organizaciones a optimizar su presupuesto y esfuerzos.
#
# ``` python
# import joblib
#
# joblib.dump(classifier, 'classifier.pkl')
#
# ```

# %%
import joblib

joblib.dump(classifier, 'classifier.pkl')
# Out:
# ['classifier.pkl']
